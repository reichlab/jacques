# %%
# %matplotlib widget

import numpy as np
import math
import tensorflow as tf
import tensorflow_probability as tfp

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

from jacques import kcqe

# %%
# Data generation adapted from https://matplotlib.org/stable/gallery/mplot3d/scatter3d.html
# Fix random state for reproducibility
np.random.seed(19680801)

def randrange(n, vmin, vmax):
    """
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    """
    return (vmax - vmin)*np.random.rand(n) + vmin

n = 500
x0 = randrange(n, -2. * np.pi, 2. * np.pi)
x1 = randrange(n, -2. * np.pi, 2. * np.pi)
y = 10. * np.cos(x0) + 0.5 * x1**2 + np.random.normal(loc=0., scale=5., size=n)

# %%
x = np.concatenate([x0[:, np.newaxis], x1[:, np.newaxis]], axis=1)
grid_size = 120
x_test = np.concatenate(
    [np.tile(np.linspace(-2. * np.pi, 2. * np.pi, num = grid_size), grid_size)[:, np.newaxis],
        np.repeat(np.linspace(-2. * np.pi, 2. * np.pi, num = grid_size), grid_size)[:, np.newaxis]],
    axis=1
)

# %%
# x_train_val
x = np.reshape(x, (1, 500, 2))
# y_train_val
y = np.reshape(y, (1, 500))

x_test = np.reshape(x_test, (1, 14400, 2))

x = tf.constant(x)
y = tf.constant(y)
x_test = tf.constant(x_test)
    
block_size = 50
num_blocks = math.floor(y.shape[1]/block_size)

# %%
kcqe_obj = kcqe.KCQE(p=2)
generator = kcqe_obj.generator(x, y, batch_size = 10, block_size = block_size)

# %%
x_val, x_train, y_val, y_train = next(generator)
print(x_val.shape)
print(y_val.shape)
print(x_train.shape)
print(y_train.shape)
# Out:
# (10, 50, 2)
# (10, 50)
# (10, 350, 2)
# (10, 350)

# %%
# plug in generator instead of raw data to get away from calculating 7-day avg
# initialize parameters at some bad values; otherwise, convergence is instantaneous
param_vec = kcqe_obj.fit(xval_batch_gen = generator,
    num_blocks = num_blocks, 
    tau=tf.constant(np.array([0.1, 0.5, 0.9])),
    optim_method="adam", 
    num_epochs=10, 
    learning_rate=0.1,
    init_param_vec=tf.constant(np.array([3.0, 3.0, 1.0])),
    verbose = True)
# Out:
# epoch idx = 0
# batch idx = 0
# loss idx = 1
# param estimates vec =
# [2.90000145 2.90000226 1.09996265]
# loss =
# 2.061065403287081
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.21835226,  0.13982425, -0.0084629 ])>]
# epoch idx = 0
# batch idx = 1
# loss idx = 1loss idx = 1
# param estimates vec =
# [2.80051068 2.79991815 1.19985514]
# loss =
# 2.0218512140830245
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.19306623,  0.14566184, -0.00823427])>]
# epoch idx = 0
# batch idx = 2
# loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [2.70085032 2.69967214 1.29862478]
# loss =
# 1.9804148457917545
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.20508295,  0.15313831, -0.00677653])>]
# epoch idx = 0
# batch idx = 3
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [2.60118828 2.59914605 1.39491129]
# loss =
# 1.947355721117355
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.20115399,  0.16514447, -0.00517849])>]
# epoch idx = 0
# batch idx = 4
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [2.50315415 2.49833607 1.48844131]
# loss =
# 1.9175063725391106
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.15342287,  0.17072184, -0.0043123 ])>]
# epoch idx = 0
# batch idx = 5
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [2.4062168  2.39744411 1.57902589]
# loss =
# 1.8821485956278812
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.1513563 ,  0.16513388, -0.00364763])>]
# epoch idx = 0
# batch idx = 6
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [2.31174179 2.29621637 1.66656605]
# loss =
# 1.840356630408363
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.11653204,  0.17762288, -0.00313627])>]
# epoch idx = 0
# batch idx = 7
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [2.21775056 2.19486363 1.75349936]
# loss =
# 1.8055374792450265
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.14216423,  0.1724794 , -0.00399822])>]
# epoch idx = 0
# batch idx = 8
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [2.12494313 2.09368753 1.83843632]
# loss =
# 1.7900674945711452
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.12420293,  0.163172  , -0.003111  ])>]
# epoch idx = 0
# batch idx = 9
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [2.03273044 1.9925378  1.92270822]
# loss =
# 1.771272194872587
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.13006358,  0.16684118, -0.00357177])>]
# epoch idx = 1
# batch idx = 0
# loss idx = 2
# param estimates vec =
# [1.94131876 1.89095026 2.00871713]
# loss =
# 1.7282894600033918
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.12264128,  0.18304981, -0.00497446])>]
# epoch idx = 1
# batch idx = 1
# loss idx = 2loss idx = 2
# param estimates vec =
# [1.85017476 1.78923417 2.09536514]
# loss =
# 1.7149240252271256
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.12962928,  0.17556603, -0.00439956])>]
# epoch idx = 1
# batch idx = 2
# loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [1.75952445 1.68765228 2.18269716]
# loss =
# 1.6736613036557926
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.12331167,  0.16825446, -0.00447109])>]
# epoch idx = 1
# batch idx = 3
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [1.66921011 1.58612261 2.26994408]
# loss =
# 1.646721811931541
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.12411905,  0.17013034, -0.00400821])>]
# epoch idx = 1
# batch idx = 4
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [1.57875111 1.48515057 2.35656192]
# loss =
# 1.6085759876172991
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.13215249,  0.15583721, -0.0036364 ])>]
# epoch idx = 1
# batch idx = 5
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [1.48894285 1.38477083 2.44191739]
# loss =
# 1.5970043949550818
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.1161088 ,  0.15261574, -0.00319176])>]
# epoch idx = 1
# batch idx = 6
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [1.40152078 1.28542327 2.5248686 ]
# loss =
# 1.5751925535152338
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.08335422,  0.13965112, -0.00247062])>]
# epoch idx = 1
# batch idx = 7
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [1.31840639 1.18759844 2.60516544]
# loss =
# 1.5548500665554923
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.04922642,  0.12527195, -0.00218382])>]
# epoch idx = 1
# batch idx = 8
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [1.23852588 1.09260995 2.68239369]
# loss =
# 1.5298820160946076
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.05750277,  0.09501433, -0.00182616])>]
# epoch idx = 1
# batch idx = 9
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [1.16236904 1.00094842 2.75627229]
# loss =
# 1.5227075548825633
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.04529536,  0.07996201, -0.0015328 ])>]
# epoch idx = 2
# batch idx = 0
# loss idx = 3
# param estimates vec =
# [1.08955916 0.91123348 2.82673066]
# loss =
# 1.5018337616287378
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.04481269,  0.09719409, -0.00133656])>]
# epoch idx = 2
# batch idx = 1
# loss idx = 3loss idx = 3
# param estimates vec =
# [1.02108925 0.82421239 2.89443334]
# loss =
# 1.5034122790946234
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.02709585,  0.07994714, -0.00146232])>]
# epoch idx = 2
# batch idx = 2
# loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [0.95795643 0.74154794 2.95854737]
# loss =
# 1.4914399277599377
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00945231,  0.0486851 , -0.00098466])>]
# epoch idx = 2
# batch idx = 3
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [0.89988507 0.66235038 3.01934751]
# loss =
# 1.489492386210965
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00676877,  0.05523078, -0.00094753])>]
# epoch idx = 2
# batch idx = 4
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [0.84874058 0.58654651 3.07671188]
# loss =
# 1.4812468413521847
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01997684,  0.05083709, -0.00076569])>]
# epoch idx = 2
# batch idx = 5
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [0.80609085 0.51552838 3.13042749]
# loss =
# 1.4767979831453668
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.0438954 ,  0.02620704, -0.00055239])>]
# epoch idx = 2
# batch idx = 6
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [0.77135547 0.44924827 3.18099537]
# loss =
# 1.4847224342031513
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.04564371,  0.02069917, -0.00061074])>]
# epoch idx = 2
# batch idx = 7
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [0.74463709 0.38760668 3.22802088]
# loss =
# 1.4880881292422243
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.05419009,  0.01616515, -0.00035051])>]
# epoch idx = 2
# batch idx = 8
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [0.72654102 0.33116437 3.27193266]
# loss =
# 1.488154384716768
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.06832059,  0.00352022, -0.00038759])>]
# epoch idx = 2
# batch idx = 9
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [0.71587976 0.27938294 3.3131036 ]
# loss =
# 1.4893376848523476
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.06381578,  0.00444218, -0.00041775])>]
# epoch idx = 3
# batch idx = 0
# loss idx = 4
# param estimates vec =
# [0.71238692 0.23271829 3.35156731]
# loss =
# 1.4857916104121833
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.06807189, -0.00626872, -0.0003381 ])>]
# epoch idx = 3
# batch idx = 1
# loss idx = 4loss idx = 4
# param estimates vec =
# [0.71585212 0.1909588  3.38744255]
# loss =
# 1.4833895499520358
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.07276514, -0.00909568, -0.00029178])>]
# epoch idx = 3
# batch idx = 2
# loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [0.72528387 0.15376684 3.42122306]
# loss =
# 1.4821303008035842
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.06867031, -0.01013198, -0.00038059])>]
# epoch idx = 3
# batch idx = 3
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [0.74075278 0.12169363 3.45289433]
# loss =
# 1.481167238708235
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.07530038, -0.021202  , -0.00030795])>]
# epoch idx = 3
# batch idx = 4
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [0.76150908 0.09428494 3.48282787]
# loss =
# 1.479546078049849
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.07294519, -0.0209765 , -0.00036747])>]
# epoch idx = 3
# batch idx = 5
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [0.78719282 0.07135051 3.51105815]
# loss =
# 1.4835828426090067
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.07413846, -0.02332   , -0.00032377])>]
# epoch idx = 3
# batch idx = 6
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [0.81699855 0.05329631 3.53768386]
# loss =
# 1.4795230435984437
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.06994779, -0.03219183, -0.00030334])>]
# epoch idx = 3
# batch idx = 7
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [0.84922044 0.03948736 3.56299474]
# loss =
# 1.479558795700906
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.05485559, -0.02965763, -0.00034865])>]
# epoch idx = 3
# batch idx = 8
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [0.88320126 0.02982332 3.58720663]
# loss =
# 1.478335952200398
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.04968625, -0.03249096, -0.00037739])>]
# epoch idx = 3
# batch idx = 9
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [0.91792444 0.02385854 3.61050432]
# loss =
# 1.4855141565476957
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.04005987, -0.03137625, -0.00040171])>]
# epoch idx = 4
# batch idx = 0
# loss idx = 5
# param estimates vec =
# [0.95260011 0.02146262 3.63299414]
# loss =
# 1.477355692114304
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.03206053, -0.03330694, -0.00040589])>]
# epoch idx = 4
# batch idx = 1
# loss idx = 5loss idx = 5
# param estimates vec =
# [0.98743304 0.02223928 3.65485889]
# loss =
# 1.4765552096494943
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.03388767, -0.03219579, -0.00043687])>]
# epoch idx = 4
# batch idx = 2
# loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [1.02067195 0.02535554 3.6760292 ]
# loss =
# 1.474077636620581
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01572053, -0.02599947, -0.00039421])>]
# epoch idx = 4
# batch idx = 3
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [1.05171935 0.03166507 3.69662792]
# loss =
# 1.4822969568523006
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.00813039, -0.03718037, -0.00040935])>]
# epoch idx = 4
# batch idx = 4
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [1.08023379 0.04038972 3.71688412]
# loss =
# 1.4738710378161628
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.00273553, -0.03167331, -0.00045972])>]
# epoch idx = 4
# batch idx = 5
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [1.1070637  0.05097428 3.73682226]
# loss =
# 1.4762707594083004
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.00882205, -0.02785757, -0.0004539 ])>]
# epoch idx = 4
# batch idx = 6
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [1.1317388  0.0631712  3.75665137]
# loss =
# 1.478555712253823
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.00271563, -0.02679623, -0.00050372])>]
# epoch idx = 4
# batch idx = 7
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [1.15416342 0.07693428 3.77585054]
# loss =
# 1.4738209288898976
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 7.33925506e-05, -2.76108046e-02, -3.43461407e-04])>]
# epoch idx = 4
# batch idx = 8
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [1.17397894 0.09199866 3.79476685]
# loss =
# 1.4699502756195573
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00538306, -0.02612728, -0.00042515])>]
# epoch idx = 4
# batch idx = 9
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [1.19072355 0.10856756 3.81334329]
# loss =
# 1.4800758050747405
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.0118596 , -0.02919661, -0.00039792])>]
# epoch idx = 5
# batch idx = 0
# loss idx = 6
# param estimates vec =
# [1.20429734 0.1248323  3.83161237]
# loss =
# 1.4637383253187108
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01525523, -0.01211707, -0.00039527])>]
# epoch idx = 5
# batch idx = 1
# loss idx = 6loss idx = 6
# param estimates vec =
# [1.21478972 0.1392242  3.84975983]
# loss =
# 1.4767613736798824
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01694592,  0.0038253 , -0.00043685])>]
# epoch idx = 5
# batch idx = 2
# loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [1.22290177 0.15324314 3.86801267]
# loss =
# 1.475780858003304
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01296508, -0.00928892, -0.00049403])>]
# epoch idx = 5
# batch idx = 3
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [1.22809595 0.1653212  3.88602362]
# loss =
# 1.471268917566371
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.0196763 ,  0.006379  , -0.00039643])>]
# epoch idx = 5
# batch idx = 4
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [1.23133155 0.17708374 3.90362711]
# loss =
# 1.4696077920180421
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01330273, -0.00765619, -0.00034184])>]
# epoch idx = 5
# batch idx = 5
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [1.23247714 0.18834975 3.92084703]
# loss =
# 1.4654020057936443
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01595679, -0.00559115, -0.0003357 ])>]
# epoch idx = 5
# batch idx = 6
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [1.2313986  0.19890426 3.93792509]
# loss =
# 1.4731872929101717
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01870622, -0.00308271, -0.00038912])>]
# epoch idx = 5
# batch idx = 7
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [1.2282885  0.2088328  3.95479393]
# loss =
# 1.4804059381617074
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.0186657 , -0.00325592, -0.00036478])>]
# epoch idx = 5
# batch idx = 8
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [1.22305701 0.21765964 3.97151553]
# loss =
# 1.4698705048400367
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.02093414,  0.00173052, -0.00037355])>]
# epoch idx = 5
# batch idx = 9
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [1.21589426 0.22554676 3.98809146]
# loss =
# 1.4787912882874725
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.02082927,  0.00114983, -0.00036777])>]
# epoch idx = 6
# batch idx = 0
# loss idx = 7
# param estimates vec =
# [1.2076706  0.23242035 4.00423085]
# loss =
# 1.4762256540898067
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01474592,  0.0026031 , -0.00028573])>]
# epoch idx = 6
# batch idx = 1
# loss idx = 7loss idx = 7
# param estimates vec =
# [1.1979544  0.23780498 4.02022751]
# loss =
# 1.466750023796767
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01914507,  0.00774303, -0.0003495 ])>]
# epoch idx = 6
# batch idx = 2
# loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [1.18711808 0.24197957 4.03608182]
# loss =
# 1.468673072494892
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01703203,  0.00640592, -0.00034384])>]
# epoch idx = 6
# batch idx = 3
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [1.17519833 0.24413878 4.05161421]
# loss =
# 1.4700640812034096
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01747625,  0.01455133, -0.00029241])>]
# epoch idx = 6
# batch idx = 4
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [1.16362384 0.24518321 4.06676484]
# loss =
# 1.472858840181573
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00631746,  0.0081104 , -0.00026783])>]
# epoch idx = 6
# batch idx = 5
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [1.15195309 0.24442466 4.08180031]
# loss =
# 1.47757093359062
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00965109,  0.01501965, -0.00032414])>]
# epoch idx = 6
# batch idx = 6
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [1.14023459 0.24351318 4.09669867]
# loss =
# 1.476092624921579
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.0092637 ,  0.00195324, -0.00031391])>]
# epoch idx = 6
# batch idx = 7
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [1.12766692 0.24184259 4.11139532]
# loss =
# 1.4684900754240076
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01575127,  0.00732046, -0.00029279])>]
# epoch idx = 6
# batch idx = 8
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [1.11432255 0.23930458 4.12585055]
# loss =
# 1.467210747203294
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01570256,  0.00880984, -0.0002766 ])>]
# epoch idx = 6
# batch idx = 9
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [1.10079057 0.23616633 4.13995147]
# loss =
# 1.4792888087891234
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01146107,  0.0071552 , -0.00024192])>]
# epoch idx = 7
# batch idx = 0
# loss idx = 8
# param estimates vec =
# [1.08772715 0.23249109 4.15381538]
# loss =
# 1.4758312972126266
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00631326,  0.00704489, -0.00026083])>]
# epoch idx = 7
# batch idx = 1
# loss idx = 8loss idx = 8
# param estimates vec =
# [1.07374259 0.22814568 4.1674731 ]
# loss =
# 1.4724101901007476
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01690489,  0.00854302, -0.00026134])>]
# epoch idx = 7
# batch idx = 2
# loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [1.06005516 0.22428797 4.18093008]
# loss =
# 1.4803507090062815
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00791844, -0.00067774, -0.00025648])>]
# epoch idx = 7
# batch idx = 3
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [1.04656208 0.22198454 4.19415753]
# loss =
# 1.4781685690377884
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00845546, -0.00990709, -0.0002437 ])>]
# epoch idx = 7
# batch idx = 4
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [1.03642126 0.22177479 4.20711667]
# loss =
# 1.4782642610101415
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01607508, -0.01549079, -0.0002281 ])>]
# epoch idx = 7
# batch idx = 5
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [1.02835558 0.22183345 4.21977543]
# loss =
# 1.4674454616931907
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.00860475, -0.00203854, -0.00021344])>]
# epoch idx = 7
# batch idx = 6
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [1.02327303 0.22285905 4.23225683]
# loss =
# 1.470651001200671
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01692816, -0.00791667, -0.00023421])>]
# epoch idx = 7
# batch idx = 7
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [1.02187814 0.22565721 4.24460728]
# loss =
# 1.4778961610133046
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.02427106, -0.01511925, -0.00023973])>]
# epoch idx = 7
# batch idx = 8
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [1.02259614 0.22792637 4.25668121]
# loss =
# 1.4769311713082767
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01490113,  0.00213617, -0.00020225])>]
# epoch idx = 7
# batch idx = 9
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [1.02602363 0.23154103 4.26852101]
# loss =
# 1.4667308652246351
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.02076233, -0.01245116, -0.00020486])>]
# epoch idx = 8
# batch idx = 0
# loss idx = 9
# param estimates vec =
# [1.03111279 0.23461703 4.28016471]
# loss =
# 1.4663298681644488
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01474928,  0.00157253, -0.00020735])>]
# epoch idx = 8
# batch idx = 1
# loss idx = 9loss idx = 9
# param estimates vec =
# [1.03714239 0.23776106 4.29165753]
# loss =
# 1.4664240476892336
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.0104891 , -0.00282192, -0.00021221])>]
# epoch idx = 8
# batch idx = 2
# loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [1.04525594 0.24153162 4.30300589]
# loss =
# 1.4651771769621853
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01948807, -0.00723255, -0.00020932])>]
# epoch idx = 8
# batch idx = 3
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [1.05304784 0.24379462 4.31423208]
# loss =
# 1.4756830793325735
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.00324019,  0.00896506, -0.00021011])>]
# epoch idx = 8
# batch idx = 4
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [1.0619247  0.24629018 4.32525613]
# loss =
# 1.4723175364676948
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01321388, -0.00345364, -0.00018883])>]
# epoch idx = 8
# batch idx = 5
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [1.06944732 0.24865184 4.33630783]
# loss =
# 1.4763542859495713
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00371333, -0.00078418, -0.00023396])>]
# epoch idx = 8
# batch idx = 6
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [1.0758638  0.25102719 4.34713669]
# loss =
# 1.461792540067021
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00282784, -0.00181201, -0.00017878])>]
# epoch idx = 8
# batch idx = 7
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [1.08073224 0.25162977 4.3579417 ]
# loss =
# 1.4768014097471498
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00669887,  0.01176392, -0.00021634])>]
# epoch idx = 8
# batch idx = 8
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [1.08289694 0.25113696 4.36859825]
# loss =
# 1.4673336926004088
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01587474,  0.00784621, -0.00018794])>]
# epoch idx = 8
# batch idx = 9
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [1.08365601 0.24994632 4.37923281]
# loss =
# 1.476242454106067
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00845275,  0.00559365, -0.00021101])>]
# epoch idx = 9
# batch idx = 0
# loss idx = 10
# param estimates vec =
# [1.0823144  0.24800629 4.38992202]
# loss =
# 1.4768675627423717
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01420551,  0.00644155, -0.00022578])>]
# epoch idx = 9
# batch idx = 1
# loss idx = 10loss idx = 10
# param estimates vec =
# [1.07899067 0.24525056 4.40066784]
# loss =
# 1.465682666881574
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01469313,  0.00742646, -0.00022614])>]
# epoch idx = 9
# batch idx = 2
# loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [1.07364705 0.24231852 4.41131345]
# loss =
# 1.4794819070710359
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01618418,  0.00323408, -0.00019316])>]
# epoch idx = 9
# batch idx = 3
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [1.06849491 0.2404803  4.42168783]
# loss =
# 1.4749235719434635
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.00217637, -0.00598878, -0.00015448])>]
# epoch idx = 9
# batch idx = 4
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [1.0623011  0.23784542 4.43195566]
# loss =
# 1.469355852632174
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.01049496,  0.00709596, -0.00018261])>]
# epoch idx = 9
# batch idx = 5
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [1.05522624 0.23564672 4.44211249]
# loss =
# 1.4662607988406047
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([ 0.010021  , -0.00134937, -0.00017871])>]
# epoch idx = 9
# batch idx = 6
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [1.04951536 0.23344341 4.45222298]
# loss =
# 1.4789901033438242
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.00468383,  0.00154415, -0.00018897])>]
# epoch idx = 9
# batch idx = 7
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [1.04609981 0.2313035  4.46242722]
# loss =
# 1.4745486102715077
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01180785,  0.0010511 , -0.00021582])>]
# epoch idx = 9
# batch idx = 8
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [1.04505764 0.23005058 4.47257097]
# loss =
# 1.4790490492832393
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01373644, -0.00488448, -0.00018521])>]
# epoch idx = 9
# batch idx = 9
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [1.04635081 0.22841137 4.48254281]
# loss =
# 1.4687780061340587
# grads =
# [<tf.Tensor: shape=(3,), dtype=float64, numpy=array([-0.01492448,  0.00359577, -0.00016063])>]

# %%
param_vec
# Out:
# <tf.Variable 'param_vec:0' shape=(3,) dtype=float64, numpy=array([1.04635081, 0.22841137, 4.48254281])>

# %%
plt.plot(np.arange(len(kcqe_obj.loss_trace)), kcqe_obj.loss_trace)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
q_hat = kcqe_obj.predict(param_vec,
                         x_train=x,
                         y_train=y,
                         x_test=x_test,
                         tau=tf.constant(np.array([0.1, 0.5, 0.9])))

# %%
fig = plt.figure(figsize=(8,8))
# ax = fig.add_subplot(111, projection='3d')
ax = Axes3D(fig)

ax.scatter(x0, x1, y)

x0_grid = x_test[..., 0].numpy().reshape((grid_size, grid_size))
x1_grid = x_test[..., 1].numpy().reshape((grid_size, grid_size))
q_grid_q10 = q_hat[..., 0].numpy().reshape((grid_size, grid_size))
q_grid_median = q_hat[..., 1].numpy().reshape((grid_size, grid_size))
q_grid_q90 = q_hat[..., 2].numpy().reshape((grid_size, grid_size))

ax.plot_wireframe(x0_grid, x1_grid, q_grid_q10, rstride=10, cstride=10, color="red")
ax.plot_wireframe(x0_grid, x1_grid, q_grid_median, rstride=10, cstride=10)
ax.plot_wireframe(x0_grid, x1_grid, q_grid_q90, rstride=10, cstride=10, color="orange")

ax.set_xlabel('X_0')
ax.set_ylabel('X_1')
ax.set_zlabel('Y')

plt.show()
# Out:
# /var/folders/xs/t5qwsz_d0hlc6vkx6wzr98f5q78pzl/T/ipykernel_29873/9007008.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
kcqe_obj = kcqe.KCQE(x_kernel='gaussian_full', p=2)
generator = kcqe_obj.generator(x, y, batch_size = 10, block_size = block_size)

# %%
# plug in generator instead of raw data to get away from calculating 7-day avg
# initialize parameters at some bad values; otherwise, convergence is instantaneous
param_vec = kcqe_obj.fit(xval_batch_gen = generator,
    num_blocks = num_blocks, 
    tau=tf.constant(np.array([0.1, 0.5, 0.9])),
    optim_method="adam", 
    num_epochs=10, 
    learning_rate=0.1,
    verbose = True)
# Out:
# epoch idx = 0
# batch idx = 0
# loss idx = 1
# param estimates vec =
# [ 0.09999891  0.09999062 -0.09998018  0.0999027 ]
# loss =
# 1.6234080034791631
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.29023406, -0.03369456,  0.01594739, -0.00324682])>]
# epoch idx = 0
# batch idx = 1
# loss idx = 1loss idx = 1
# param estimates vec =
# [ 0.19978717  0.19867518 -0.08452612  0.19827   ]
# loss =
# 1.5884111692947218
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.27268864, -0.0265557 , -0.01959987, -0.00248559])>]
# epoch idx = 0
# batch idx = 2
# loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [ 0.29868352  0.28815353 -0.04835643  0.29745958]
# loss =
# 1.5632922821737107
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.234777  , -0.0106957 , -0.01083722, -0.0031209 ])>]
# epoch idx = 0
# batch idx = 3
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [ 0.39627454  0.37089775 -0.03357946  0.39718597]
# loss =
# 1.5411026475153662
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.20419622, -0.00827509,  0.00680801, -0.00325581])>]
# epoch idx = 0
# batch idx = 4
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [ 0.49154227  0.43891085 -0.04927686  0.49530641]
# loss =
# 1.5225742529768347
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.16317445,  0.0015511 ,  0.01579931, -0.00229607])>]
# epoch idx = 0
# batch idx = 5
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [ 0.58356597  0.47063538 -0.07079069  0.59426068]
# loss =
# 1.5088135522330703
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.12719212,  0.02044058,  0.00511777, -0.00322257])>]
# epoch idx = 0
# batch idx = 6
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [ 0.67154496  0.48454022 -0.06603409  0.69411863]
# loss =
# 1.5033045615863916
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.09674232,  0.01298021, -0.01556538, -0.00503498])>]
# epoch idx = 0
# batch idx = 7
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [ 0.75437936  0.50149856 -0.04041007  0.79496035]
# loss =
# 1.4963035091767627
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.0652784 , -0.0049139 , -0.01781406, -0.00428747])>]
# epoch idx = 0
# batch idx = 8
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [ 0.83212459  0.49810921 -0.01515322  0.89603236]
# loss =
# 1.485316149454542
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.05177763,  0.01956615, -0.00210146, -0.00375066])>]
# epoch idx = 0
# batch idx = 9
# loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1loss idx = 1
# param estimates vec =
# [ 0.90476348  0.48292171 -0.00219026  0.99458485]
# loss =
# 1.4882781949328354
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.03963214,  0.01432932,  0.00779141, -0.00232717])>]
# epoch idx = 1
# batch idx = 0
# loss idx = 2
# param estimates vec =
# [ 0.97236375  0.44800879 -0.01649712  1.09255679]
# loss =
# 1.4785502980567924
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.03020208,  0.030614  ,  0.02405271, -0.00296884])>]
# epoch idx = 1
# batch idx = 1
# loss idx = 2loss idx = 2
# param estimates vec =
# [ 1.03284663  0.39875073 -0.04650842  1.19026052]
# loss =
# 1.4831779539589656
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00346654,  0.03120033,  0.0193126 , -0.00306487])>]
# epoch idx = 1
# batch idx = 2
# loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [ 1.0873274   0.34253039 -0.0904369   1.28358655]
# loss =
# 1.4667678138135012
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.0005189 ,  0.02105383,  0.0221506 , -0.00142706])>]
# epoch idx = 1
# batch idx = 3
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [ 1.13640606  0.28975724 -0.13033493  1.37559755]
# loss =
# 1.4687716588460984
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00162178,  0.00312349,  0.00024585, -0.00226884])>]
# epoch idx = 1
# batch idx = 4
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [ 1.18084472  0.23974129 -0.16193234  1.46645864]
# loss =
# 1.4702032526539017
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.0002712 ,  0.00354566, -0.00503811, -0.00224471])>]
# epoch idx = 1
# batch idx = 5
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [ 1.22025938  0.19758144 -0.14855552  1.55807002]
# loss =
# 1.475833914961524
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00974348, -0.00469735, -0.05415486, -0.0029495 ])>]
# epoch idx = 1
# batch idx = 6
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [ 1.25564071  0.16966407 -0.1188229   1.64856287]
# loss =
# 1.4776661356242418
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00429287, -0.01482136, -0.03152105, -0.00221591])>]
# epoch idx = 1
# batch idx = 7
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [ 1.28636908  0.15447297 -0.07979929  1.73996993]
# loss =
# 1.4815696366492896
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01564191, -0.01509295, -0.02268141, -0.00297394])>]
# epoch idx = 1
# batch idx = 8
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [ 1.31318718  0.15425136 -0.04273846  1.83055856]
# loss =
# 1.471530918314391
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01228338, -0.02096946, -0.00279756, -0.00230427])>]
# epoch idx = 1
# batch idx = 9
# loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2loss idx = 2
# param estimates vec =
# [ 1.33576757  0.15563131 -0.03195603  1.92094377]
# loss =
# 1.4815572958756156
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.0197828 , -0.00250537,  0.03768515, -0.00249132])>]
# epoch idx = 2
# batch idx = 0
# loss idx = 3
# param estimates vec =
# [ 1.35454049  0.16133943 -0.03940773  2.01104439]
# loss =
# 1.4712708622786106
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01922039, -0.00701172,  0.03274542, -0.00243972])>]
# epoch idx = 2
# batch idx = 1
# loss idx = 3loss idx = 3
# param estimates vec =
# [ 1.3700633   0.1682184  -0.06141756  2.10076861]
# loss =
# 1.469152002519432
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01682065, -0.00262389,  0.03154062, -0.00238146])>]
# epoch idx = 2
# batch idx = 2
# loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [ 1.38130748  0.17312813 -0.08622556  2.19048872]
# loss =
# 1.4746000253877574
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.03067344,  0.00207978,  0.00978061, -0.00249623])>]
# epoch idx = 2
# batch idx = 3
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [ 1.38879887  0.17743009 -0.11281044  2.27812564]
# loss =
# 1.4669699526931888
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.02894597,  0.00025769,  0.00810382, -0.00174554])>]
# epoch idx = 2
# batch idx = 4
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [ 1.39278354  0.17669263 -0.13840977  2.36443323]
# loss =
# 1.4840242592879314
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.02962718,  0.0069998 ,  0.00274658, -0.0019133 ])>]
# epoch idx = 2
# batch idx = 5
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [ 1.3950871   0.17778009 -0.14244823  2.44911246]
# loss =
# 1.4792785114273113
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01371381, -0.00262206, -0.03712821, -0.00175668])>]
# epoch idx = 2
# batch idx = 6
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [ 1.39598386  0.19028477 -0.13330042  2.53215337]
# loss =
# 1.4750257155665285
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01228315, -0.017377  , -0.02671471, -0.00168856])>]
# epoch idx = 2
# batch idx = 7
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [ 1.39534072  0.21057351 -0.11126251  2.61367625]
# loss =
# 1.4724112921173258
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01474824, -0.01364581, -0.02993644, -0.00166319])>]
# epoch idx = 2
# batch idx = 8
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [ 1.3918445   0.22139126 -0.09468307  2.69348874]
# loss =
# 1.4786792898650116
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.02908751,  0.01127705,  0.00734046, -0.00154618])>]
# epoch idx = 2
# batch idx = 9
# loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3loss idx = 3
# param estimates vec =
# [ 1.38592097  0.21339153 -0.08561221  2.7716827 ]
# loss =
# 1.4778038013522885
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.02709409,  0.0271128 ,  0.01253546, -0.00151255])>]
# epoch idx = 3
# batch idx = 0
# loss idx = 4
# param estimates vec =
# [ 1.37742251  0.20093502 -0.07701055  2.84752505]
# loss =
# 1.474465193597774
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.03039958,  0.00804212, -0.00070236, -0.00124183])>]
# epoch idx = 3
# batch idx = 1
# loss idx = 4loss idx = 4
# param estimates vec =
# [ 1.36690909  0.19116342 -0.06960952  2.92075938]
# loss =
# 1.4646575968642288
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.02687997, -0.00240409,  0.00089415, -0.00109751])>]
# epoch idx = 3
# batch idx = 2
# loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [ 1.35487524  0.18384648 -0.06834435  2.99142545]
# loss =
# 1.471242246481849
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.02356939, -0.0023895 ,  0.01111137, -0.00103292])>]
# epoch idx = 3
# batch idx = 3
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [ 1.34129501  0.18103382 -0.07520602  3.0598893 ]
# loss =
# 1.4776888804763733
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.02486842, -0.00574291,  0.01627763, -0.00105929])>]
# epoch idx = 3
# batch idx = 4
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [ 1.32613987  0.17976277 -0.08623618  3.12632674]
# loss =
# 1.4786954771870366
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.02619486, -0.00190786,  0.00967917, -0.00104335])>]
# epoch idx = 3
# batch idx = 5
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [ 1.30910558  0.17471317 -0.10300747  3.19038826]
# loss =
# 1.468671500198092
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.03011682,  0.00570394,  0.01361327, -0.00089455])>]
# epoch idx = 3
# batch idx = 6
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [ 1.29276237  0.17288818 -0.10480833  3.25208096]
# loss =
# 1.4750622528309691
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00763414, -0.00401153, -0.02661232, -0.00083343])>]
# epoch idx = 3
# batch idx = 7
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [ 1.27671298  0.17797421 -0.09125557  3.31165789]
# loss =
# 1.4713465178429954
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.0106121 , -0.00970915, -0.03130782, -0.00083604])>]
# epoch idx = 3
# batch idx = 8
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [ 1.26088148  0.19059248 -0.07903229  3.36836192]
# loss =
# 1.4785630096271973
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.0109568 , -0.01152928,  0.00023265, -0.00059442])>]
# epoch idx = 3
# batch idx = 9
# loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4loss idx = 4
# param estimates vec =
# [ 1.24523688  0.19659543 -0.07887139  3.42294953]
# loss =
# 1.4719020000348622
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01095517,  0.00775497,  0.02215684, -0.00071051])>]
# epoch idx = 4
# batch idx = 0
# loss idx = 5
# param estimates vec =
# [ 1.22951808  0.19590064 -0.08865535  3.47560719]
# loss =
# 1.471669122696352
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01300322,  0.00868615,  0.02038428, -0.00070347])>]
# epoch idx = 4
# batch idx = 1
# loss idx = 5loss idx = 5
# param estimates vec =
# [ 1.21501605  0.19768248 -0.09366402  3.52625267]
# loss =
# 1.4739837689642863
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00172646, -0.0033836 , -0.00788918, -0.00063667])>]
# epoch idx = 4
# batch idx = 2
# loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [ 1.20183229  0.20553335 -0.09066754  3.57494636]
# loss =
# 1.4646770025446985
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-8.45896001e-05, -8.68908959e-03, -1.52408496e-02, -6.03067167e-04])>]
# epoch idx = 4
# batch idx = 3
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [ 1.18937235  0.21413293 -0.08445839  3.62144195]
# loss =
# 1.479475327980554
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00396415, -0.00201265, -0.00699935, -0.00050064])>]
# epoch idx = 4
# batch idx = 4
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [ 1.17768861  0.2201807  -0.08087327  3.66594024]
# loss =
# 1.4706183604437577
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.0029478 ,  0.00241682,  0.00409242, -0.00049725])>]
# epoch idx = 4
# batch idx = 5
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [ 1.16694209  0.23278451 -0.07131502  3.70882266]
# loss =
# 1.4642045500478416
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00100981, -0.00969108, -0.01246841, -0.00053865])>]
# epoch idx = 4
# batch idx = 6
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [ 1.15624647  0.23103142 -0.0671318   3.75007585]
# loss =
# 1.4741875353956726
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00760369,  0.01780843,  0.00879532, -0.00049883])>]
# epoch idx = 4
# batch idx = 7
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [ 1.14668197  0.23301991 -0.06237937  3.78912356]
# loss =
# 1.474274394474145
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00129293, -0.00486056, -0.0018426 , -0.00033593])>]
# epoch idx = 4
# batch idx = 8
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [ 1.13718026  0.23396311 -0.05909816  3.8267146 ]
# loss =
# 1.470765409125701
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00651184,  0.00116172,  0.00199431, -0.00045278])>]
# epoch idx = 4
# batch idx = 9
# loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5loss idx = 5
# param estimates vec =
# [ 1.12925042  0.23287116 -0.05066014  3.86291551]
# loss =
# 1.4670915769665802
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00562604,  0.00259547, -0.01042794, -0.00043521])>]
# epoch idx = 5
# batch idx = 0
# loss idx = 6
# param estimates vec =
# [ 1.12038949  0.22313664 -0.05221185  3.89780298]
# loss =
# 1.4705143234145293
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01309416,  0.01163032,  0.01744816, -0.00042138])>]
# epoch idx = 5
# batch idx = 1
# loss idx = 6loss idx = 6
# param estimates vec =
# [ 1.11222812  0.20644702 -0.05711716  3.9312189 ]
# loss =
# 1.4704939681113356
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00086469,  0.01046433,  0.00660985, -0.00035971])>]
# epoch idx = 5
# batch idx = 2
# loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [ 1.1059169   0.20414911 -0.06554449  3.96319485]
# loss =
# 1.4717899338298441
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00854864, -0.01683548,  0.00745971, -0.00033576])>]
# epoch idx = 5
# batch idx = 3
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [ 1.10091419  0.20613208 -0.07266982  3.99380744]
# loss =
# 1.4681373371314754
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.005608  , -0.00537996, -0.00098359, -0.00032208])>]
# epoch idx = 5
# batch idx = 4
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [ 1.09719502  0.21117621 -0.0715535   4.02346091]
# loss =
# 1.4674777873015932
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00627637, -0.00425782, -0.01398249, -0.00037709])>]
# epoch idx = 5
# batch idx = 5
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [ 1.09412354  0.21981709 -0.06962963  4.05211332]
# loss =
# 1.4649426416689872
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00230868, -0.00529726, -0.00167009, -0.0003481 ])>]
# epoch idx = 5
# batch idx = 6
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [ 1.09217484  0.23188878 -0.0605043   4.07989573]
# loss =
# 1.4673906630274316
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00628493, -0.00548076, -0.01350105, -0.00035358])>]
# epoch idx = 5
# batch idx = 7
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [ 1.09055882  0.23988272 -0.04541697  4.1067627 ]
# loss =
# 1.4731117513734584
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.0011359 ,  0.00379346, -0.01243892, -0.00032618])>]
# epoch idx = 5
# batch idx = 8
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [ 1.08928838  0.24927776 -0.02981564  4.13257314]
# loss =
# 1.4777282886049692
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00144518, -0.00272472, -0.00344658, -0.00027951])>]
# epoch idx = 5
# batch idx = 9
# loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6loss idx = 6
# param estimates vec =
# [ 1.08668289  0.24776653 -0.02827905  4.15725033]
# loss =
# 1.4782503759145729
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01059477,  0.0126819 ,  0.02254935, -0.00024367])>]
# epoch idx = 6
# batch idx = 0
# loss idx = 7
# param estimates vec =
# [ 1.08261032  0.24123772 -0.03618577  4.18126235]
# loss =
# 1.4714425742883035
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01236135,  0.00652691,  0.01683063, -0.00031262])>]
# epoch idx = 6
# batch idx = 1
# loss idx = 7loss idx = 7
# param estimates vec =
# [ 1.07864412  0.23672102 -0.04194853  4.2046084 ]
# loss =
# 1.4726411704088236
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00194205, -0.001765  , -0.00253523, -0.00029859])>]
# epoch idx = 6
# batch idx = 2
# loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [ 1.07611417  0.22881468 -0.04657397  4.22694891]
# loss =
# 1.4719425032737739
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00760489,  0.00475115, -0.00107504, -0.00022016])>]
# epoch idx = 6
# batch idx = 3
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [ 1.07416517  0.22577182 -0.04961341  4.24861933]
# loss =
# 1.4679667191901196
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00244488, -0.00509987, -0.00204511, -0.00026463])>]
# epoch idx = 6
# batch idx = 4
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [ 1.07252934  0.22918837 -0.05876882  4.26981466]
# loss =
# 1.4747434604730427
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00092596, -0.00759815,  0.01127886, -0.00028791])>]
# epoch idx = 6
# batch idx = 5
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [ 1.07058623  0.22884063 -0.06738217  4.29045511]
# loss =
# 1.4666418025701793
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00319376,  0.00421298,  0.00054005, -0.000263  ])>]
# epoch idx = 6
# batch idx = 6
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [ 1.06925386  0.2292265  -0.07104017  4.31062455]
# loss =
# 1.470410404885359
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00296581, -0.00085134, -0.00719148, -0.00026734])>]
# epoch idx = 6
# batch idx = 7
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [ 1.06870369  0.23192079 -0.06968343  4.3303017 ]
# loss =
# 1.4647187213016335
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00450573, -0.00282606, -0.008055  , -0.00025374])>]
# epoch idx = 6
# batch idx = 8
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [ 1.06819567  0.23246379 -0.0631658   4.34945328]
# loss =
# 1.4717310970897834
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 6.21529366e-05,  2.27308456e-03, -9.07839950e-03, -2.37789293e-04])>]
# epoch idx = 6
# batch idx = 9
# loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7loss idx = 7
# param estimates vec =
# [ 1.06935728  0.2301405  -0.05528269  4.36787952]
# loss =
# 1.4720316583238098
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.0109454 ,  0.00334639, -0.00336632, -0.00019143])>]
# epoch idx = 7
# batch idx = 0
# loss idx = 8
# param estimates vec =
# [ 1.07021965  0.21609296 -0.04830685  4.38578766]
# loss =
# 1.4761481937025733
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00127756,  0.01426647,  0.00028895, -0.00021534])>]
# epoch idx = 7
# batch idx = 1
# loss idx = 8loss idx = 8
# param estimates vec =
# [ 1.07182291  0.21287317 -0.03882278  4.4033396 ]
# loss =
# 1.4672454552691583
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00546426, -0.01123994, -0.00531972, -0.00023428])>]
# epoch idx = 7
# batch idx = 2
# loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [ 1.07435376  0.22385833 -0.03346891  4.42036419]
# loss =
# 1.467303187656194
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00711803, -0.01663143,  0.00540484, -0.00019676])>]
# epoch idx = 7
# batch idx = 3
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [ 1.07840625  0.2425596  -0.02800893  4.43683053]
# loss =
# 1.4616013553624907
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.01153991, -0.01053949, -0.00100791, -0.00018156])>]
# epoch idx = 7
# batch idx = 4
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [ 1.08161973  0.26075964 -0.02356868  4.45303302]
# loss =
# 1.4727953190608023
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00299051, -0.00149158,  0.00083635, -0.00022272])>]
# epoch idx = 7
# batch idx = 5
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [ 1.08190029  0.26800306 -0.02791805  4.46882405]
# loss =
# 1.4791814768057332
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01702499,  0.01087869,  0.01373108, -0.00019161])>]
# epoch idx = 7
# batch idx = 6
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [ 1.08131428  0.26803025 -0.03478136  4.48442666]
# loss =
# 1.4671097244234486
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00540252,  0.00771478,  0.00477756, -0.00022223])>]
# epoch idx = 7
# batch idx = 7
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [ 1.07881969  0.25981113 -0.04824051  4.49985505]
# loss =
# 1.4716693764785809
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01254629,  0.0097376 ,  0.01182672, -0.00022037])>]
# epoch idx = 7
# batch idx = 8
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [ 1.07675503  0.24530773 -0.05694915  4.51502835]
# loss =
# 1.477740039122312
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00123963,  0.00833781, -0.00562615, -0.00020263])>]
# epoch idx = 7
# batch idx = 9
# loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8loss idx = 8
# param estimates vec =
# [ 1.07654005  0.23695092 -0.05871217  4.52977353]
# loss =
# 1.4615251024858245
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.01043791, -0.00557862, -0.00984674, -0.0001683 ])>]
# epoch idx = 8
# batch idx = 0
# loss idx = 9
# param estimates vec =
# [ 1.07655009  0.22567875 -0.05129141  4.54437983]
# loss =
# 1.4704531290465344
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00128317,  0.00432088, -0.01450924, -0.00020908])>]
# epoch idx = 8
# batch idx = 1
# loss idx = 9loss idx = 9
# param estimates vec =
# [ 1.07683785  0.21671008 -0.04238369  4.55872461]
# loss =
# 1.4776999945197
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00173508, -0.00143561, -0.00350303, -0.00018534])>]
# epoch idx = 8
# batch idx = 2
# loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [ 1.07683033  0.20685421 -0.04022999  4.57279358]
# loss =
# 1.4761034866324723
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00165909,  0.00199585,  0.00939955, -0.00017791])>]
# epoch idx = 8
# batch idx = 3
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [ 1.07578458  0.20340963 -0.04896084  4.58657077]
# loss =
# 1.4668514328871403
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00638889, -0.00626011,  0.0170206 , -0.00017006])>]
# epoch idx = 8
# batch idx = 4
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [ 1.0765936   0.20896268 -0.06207033  4.59995448]
# loss =
# 1.4720311485005078
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.01073311, -0.00990315,  0.00828582, -0.00014806])>]
# epoch idx = 8
# batch idx = 5
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [ 1.07723633  0.22159042 -0.07899221  4.61324691]
# loss =
# 1.4666093702778453
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00054579, -0.00869045,  0.00801659, -0.00019032])>]
# epoch idx = 8
# batch idx = 6
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [ 1.07839687  0.23138552 -0.09097068  4.62645014]
# loss =
# 1.4788415035286224
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00349443,  0.00185637, -0.00524216, -0.00018826])>]
# epoch idx = 8
# batch idx = 7
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [ 1.08085527  0.24260465 -0.09556035  4.63972486]
# loss =
# 1.4743375867399693
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00845275, -0.00265474, -0.0097634 , -0.00021171])>]
# epoch idx = 8
# batch idx = 8
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [ 1.08279071  0.25099236 -0.0932468   4.65287499]
# loss =
# 1.4716709494218867
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00173216,  0.00198196, -0.01008612, -0.00018041])>]
# epoch idx = 8
# batch idx = 9
# loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9loss idx = 9
# param estimates vec =
# [ 1.08453837  0.25122764 -0.08800911  4.66579871]
# loss =
# 1.4764965857571855
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 2.62232396e-05,  8.20255619e-03, -4.88500990e-03, -1.61471764e-04])>]
# epoch idx = 9
# batch idx = 0
# loss idx = 10
# param estimates vec =
# [ 1.08671152  0.25534062 -0.07896144  4.67851571]
# loss =
# 1.477796969332179
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00348811, -0.00434073, -0.00666652, -0.00016038])>]
# epoch idx = 9
# batch idx = 1
# loss idx = 10loss idx = 10
# param estimates vec =
# [ 1.08772884  0.25983287 -0.07511824  4.69108592]
# loss =
# 1.4651813475340696
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00557139, -0.00085157,  0.00667575, -0.00016591])>]
# epoch idx = 9
# batch idx = 2
# loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [ 1.08790487  0.25844688 -0.07002135  4.70354726]
# loss =
# 1.4693241922498168
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00434465,  0.00600195, -0.0024779 , -0.00016882])>]
# epoch idx = 9
# batch idx = 3
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [ 1.08813533  0.2599811  -0.067548    4.71605119]
# loss =
# 1.4745157994065885
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.0004127 , -0.00305733,  0.00325562, -0.00018987])>]
# epoch idx = 9
# batch idx = 4
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [ 1.08923787  0.26231207 -0.05843199  4.72856136]
# loss =
# 1.4697621626045239
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00515802, -0.00102796, -0.01044917, -0.00018395])>]
# epoch idx = 9
# batch idx = 5
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [ 1.09059872  0.26528396 -0.04758207  4.74109904]
# loss =
# 1.4758511740454519
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.0020836 , -0.00093557, -0.00393186, -0.00018641])>]
# epoch idx = 9
# batch idx = 6
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [ 1.09141851  0.26254794 -0.04229651  4.75344902]
# loss =
# 1.4706127033543142
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.00234923,  0.00585738,  0.00679946, -0.00015308])>]
# epoch idx = 9
# batch idx = 7
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [ 1.0894435   0.24932436 -0.04670093  4.76562267]
# loss =
# 1.4659972133476065
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.01542648,  0.01163973,  0.01377073, -0.00015137])>]
# epoch idx = 9
# batch idx = 8
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [ 1.08723449  0.23320454 -0.04858012  4.7776364 ]
# loss =
# 1.4658913238272553
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 0.0023838 ,  0.00448547, -0.00314664, -0.0001506 ])>]
# epoch idx = 9
# batch idx = 9
# loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10loss idx = 10
# param estimates vec =
# [ 1.08552133  0.22051283 -0.04807476  4.78948439]
# loss =
# 1.4776213845650294
# grads =
# [<tf.Tensor: shape=(4,), dtype=float64, numpy=array([-0.00160395, -0.00202475, -0.00327977, -0.00014674])>]

# %%
q_hat = kcqe_obj.predict(param_vec,
                         x_train=x,
                         y_train=y,
                         x_test=x_test,
                         tau=tf.constant(np.array([0.1, 0.5, 0.9])))

# %%
fig = plt.figure(figsize=(8,8))
# ax = fig.add_subplot(111, projection='3d')
ax = Axes3D(fig)

ax.scatter(x0, x1, y)

x0_grid = x_test[..., 0].numpy().reshape((grid_size, grid_size))
x1_grid = x_test[..., 1].numpy().reshape((grid_size, grid_size))
q_grid_q10 = q_hat[..., 0].numpy().reshape((grid_size, grid_size))
q_grid_median = q_hat[..., 1].numpy().reshape((grid_size, grid_size))
q_grid_q90 = q_hat[..., 2].numpy().reshape((grid_size, grid_size))

ax.plot_wireframe(x0_grid, x1_grid, q_grid_q10, rstride=10, cstride=10, color="red")
ax.plot_wireframe(x0_grid, x1_grid, q_grid_median, rstride=10, cstride=10)
ax.plot_wireframe(x0_grid, x1_grid, q_grid_q90, rstride=10, cstride=10, color="orange")

ax.set_xlabel('X_0')
ax.set_ylabel('X_1')
ax.set_zlabel('Y')

plt.show()
# Out:
# /var/folders/xs/t5qwsz_d0hlc6vkx6wzr98f5q78pzl/T/ipykernel_29873/9007008.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
